# %%
import folium
import pandas as pd
from branca.element import Figure

# %%
data_tables = ['agency', 'calendar_dates', 'calendar', 'routes', 'shapes', 'stop_times', 'stops', 'trips']

# %%
# import csv data

for table in data_tables:
    globals()[table] = pd.read_csv(f'raw-data/ttc-schedule-data/{table}.txt')

# %%
# stops = pd.read_feather('data/stops.ftr')

# %%
stops.head(3)
# Out:
#    stop_id  stop_code                   stop_name  stop_desc   stop_lat  \
# 0      262        662   Danforth Rd at Kennedy Rd        NaN  43.714379
# 1      263        929  Davenport Rd at Bedford Rd        NaN  43.674448
# 2      264        940   Davenport Rd at Dupont St        NaN  43.675511
#
#     stop_lon  zone_id  stop_url  location_type  parent_station  stop_timezone  \
# 0 -79.260939      NaN       NaN            NaN             NaN            NaN
# 1 -79.399659      NaN       NaN            NaN             NaN            NaN
# 2 -79.401938      NaN       NaN            NaN             NaN            NaN
#
#    wheelchair_boarding
# 0                    2
# 1                    1
# 2                    2

# %%
stops[stops.stop_name.str.contains('1222 York Mills')]
# Out:
#      stop_id  stop_code                                       stop_name  \
# 452      917       9083  York Mills Rd at Sandover Dr (1222 York Mills)
#
#      stop_desc   stop_lat   stop_lon  zone_id  stop_url  location_type  \
# 452        NaN  43.759813 -79.331751      NaN       NaN            NaN
#
#      parent_station  stop_timezone  wheelchair_boarding
# 452             NaN            NaN                    1

# %%
home = stops[stops.stop_id == 917]

# %%
# my_first_map = folium.Map(location = [home.stop_lat, home.stop_lon], zoom_start = 20)

# %%
# folium.Marker(location = [home.stop_lat, home.stop_lon]).add_to(my_first_map)

# %%
stops_sample = stops.sample(100)
stops_sample = stops_sample.reset_index(drop = False)
stops_sample
# Out:
#     index  stop_id  stop_code                               stop_name  \
# 0    1037     1603       9290                 Drewry Ave at Hilda Ave
# 1    2109     2899       2468               Faywood Blvd at Faith Ave
# 2    4775     6130         80               Bathurst St at Alcina Ave
# 3    3910     5093       5326  Lawrence Ave East at Victoria Park Ave
# 4    7184     9006       7278         Sheppard Ave West at Fennell St
# ..    ...      ...        ...                                     ...
# 95   8065    10059      10447                            2900 Jane St
# 96   3318     4366       1184               Jones Ave at Danforth Ave
# 97   9212    23894      15647   King St West at Spadina Ave West Side
# 98   8742    14460      13800  St Clair Station - Northbound Platform
# 99   7712     9637       4701              Washburn Way at Griffen Dr
#
#     stop_desc   stop_lat   stop_lon  zone_id  stop_url  location_type  \
# 0         NaN  43.785533 -79.424220      NaN       NaN            NaN
# 1         NaN  43.739215 -79.447563      NaN       NaN            NaN
# 2         NaN  43.680169 -79.417216      NaN       NaN            NaN
# 3         NaN  43.742302 -79.309589      NaN       NaN            NaN
# 4         NaN  43.759163 -79.421219      NaN       NaN            NaN
# ..        ...        ...        ...      ...       ...            ...
# 95        NaN  43.752642 -79.516653      NaN       NaN            NaN
# 96        NaN  43.679674 -79.339967      NaN       NaN            NaN
# 97        NaN  43.645370 -79.395811      NaN       NaN            NaN
# 98        NaN  43.688649 -79.393489      NaN       NaN            NaN
# 99        NaN  43.798171 -79.228060      NaN       NaN            NaN
#
#     parent_station  stop_timezone  wheelchair_boarding
# 0              NaN            NaN                    1
# 1              NaN            NaN                    1
# 2              NaN            NaN                    1
# 3              NaN            NaN                    1
# 4              NaN            NaN                    1
# ..             ...            ...                  ...
# 95             NaN            NaN                    1
# 96             NaN            NaN                    1
# 97             NaN            NaN                    1
# 98             NaN            NaN                    1
# 99             NaN            NaN                    2
#
# [100 rows x 13 columns]

# %%
stops_map = folium.Map(location = [stops_sample.stop_lat.mean(), stops_sample.stop_lon.mean()], zoom_start = 12, width = 800, height = 600)

# %%
for i in range(0, len(stops_sample)):
    marker_color = ''
    if (stops_sample.wheelchair_boarding[i] == 1):
        marker_color = 'green'
    else:
        marker_color = 'red'
    folium.Marker(
                    location = [stops_sample.stop_lat[i], stops_sample.stop_lon[i]],
                    popup = stops_sample.stop_name[i],
                    tooltip = stops_sample.stop_code[i],
                    icon = folium.Icon(color = marker_color, prefix = 'fa', icon = 'bus')
                 ).add_to(stops_map)

# %%
fig = Figure(width = 800, height = 600)
fig.add_child(stops_map)
fig
# Out:
# <iframe src="about:blank" width="800" height="600"style="border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_0d3e7484a1d04f5bbe4157c914a37d33%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20800.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20600.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_0d3e7484a1d04f5bbe4157c914a37d33%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_0d3e7484a1d04f5bbe4157c914a37d33%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_0d3e7484a1d04f5bbe4157c914a37d33%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.71971836999998%2C%20-79.39191435000002%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2012%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20 ...

# %%
stops_map.save('test_map.html')

# %%
shapes
# Out:
#         shape_id  shape_pt_lat  shape_pt_lon  shape_pt_sequence  \
# 0         886387     43.775608    -79.346046                  1
# 1         886387     43.775536    -79.346361                  2
# 2         886387     43.775521    -79.346449                  3
# 3         886387     43.775518    -79.346575                  4
# 4         886387     43.775544    -79.346697                  5
# ...          ...           ...           ...                ...
# 352015    890357     43.762831    -79.404955                 50
# 352016    890357     43.762279    -79.407368                 51
# 352017    890357     43.762048    -79.408461                 52
# 352018    890357     43.761750    -79.409808                 53
# 352019    890357     43.761454    -79.411135                 54
#
#         shape_dist_traveled
# 0                    0.0000
# 1                    0.0262
# 2                    0.0335
# 3                    0.0435
# 4                    0.0540
# ...                     ...
# 352015               4.8289
# 352016               5.0313
# 352017               5.1230
# 352018               5.2360
# 352019               5.3470
#
# [352020 rows x 5 columns]

# %%
shapes.shape_id.value_counts()
# Out:
# 886877    1368
# 886878    1258
# 886846    1190
# 888163    1036
# 888164    1036
#           ...
# 887258      10
# 888033       9
# 887247       8
# 886935       8
# 888074       7
# Name: shape_id, Length: 1375, dtype: int64

# %%
first_shape = shapes[shapes.shape_id == 886877]
first_shape = first_shape.reset_index(drop = True)

# %%
first_shape.shape_id.value_counts()
# Out:
# 886877    1368
# Name: shape_id, dtype: int64

# %%
first_shape.head(3)
# Out:
#    shape_id  shape_pt_lat  shape_pt_lon  shape_pt_sequence  \
# 0    886877     43.694286    -79.274007                  1
# 1    886877     43.693986    -79.275447                  2
# 2    886877     43.693742    -79.276736                  3
#
#    shape_dist_traveled
# 0               0.0000
# 1               0.1209
# 2               0.2274

# %%
first_shape.tail(3)
# Out:
#       shape_id  shape_pt_lat  shape_pt_lon  shape_pt_sequence  \
# 1365    886877     43.686819    -79.621074               1366
# 1366    886877     43.686336    -79.620562               1367
# 1367    886877     43.685934    -79.619788               1368
#
#       shape_dist_traveled
# 1365              38.2609
# 1366              38.3287
# 1367              38.4053

# %%
[first_shape.shape_pt_lat[0], first_shape.shape_pt_lon[0]]
# Out:
# [43.694286, -79.274007]

# %%
first_shape_route = []
first_shape_route.append(['1', '2'])
first_shape_route
# Out:
# [['1', '2']]

# %%
first_shape_route = []
for i in range(0, len(first_shape)):
    first_shape_route.append([first_shape.shape_pt_lat[i], first_shape.shape_pt_lon[i]])

# %%
first_shape_route[0:10]
# Out:
# [[43.694286, -79.274007],
#  [43.693985999999995, -79.275447],
#  [43.693742, -79.276736],
#  [43.693639000000005, -79.277277],
#  [43.693546000000005, -79.277825],
#  [43.693518, -79.27793299999999],
#  [43.693303, -79.278948],
#  [43.693049, -79.280039],
#  [43.693025, -79.280171],
#  [43.692901, -79.280741]]

# %%
shape_map = folium.Map(location = [first_shape.shape_pt_lat.mean(), first_shape.shape_pt_lon.mean()], zoom_start = 12)

folium.PolyLine(first_shape_route).add_to(shape_map)

for i in [0, len(first_shape) - 1]:
    folium.Marker(
        location = [first_shape.shape_pt_lat[i], first_shape.shape_pt_lon[i]],
        tooltip = first_shape.shape_id[i],
        popup = f'{first_shape.shape_pt_sequence[i]}, {first_shape.shape_dist_traveled[i]}',
        icon = folium.Icon(color = marker_color, prefix = 'fa', icon = 'bus')
    ).add_to(shape_map)
# fig = Figure(width = 800, height = 600)
# fig.add_child(shape_map)
# fig
shape_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_c930db60e2c644a7b83ae502ee4929cd%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c930db60e2c644a7b83ae502ee4929cd%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_c930db60e2c644a7b83ae502ee4929cd%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_c930db60e2c644a7b83ae502ee4929cd%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6635875438596%2C%20-79.53118558845033%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
# route

# map
map_plot_route = folium.Map(location=[38, -98], zoom_start=4)

# route_locs = ['Los Angeles', 'Las Vegas', 'Denver', 'Chicago', 'Manhattan']
# can use list of lists or list of tuples
route_lats_longs = [[34.041008,-118.246653],
                    [36.169726,-115.143996], 
                    [39.739448,-104.992450], 
                    [41.878765,-87.643267], 
                    [40.782949,-73.969559]]

# add route to map
folium.PolyLine(route_lats_longs).add_to(map_plot_route)

# display map
map_plot_route
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_444387b7b17c4d69b22f49bce31fbf3f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_444387b7b17c4d69b22f49bce31fbf3f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_444387b7b17c4d69b22f49bce31fbf3f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_444387b7b17c4d69b22f49bce31fbf3f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B38.0%2C%20-98.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20c ...

# %%
stops_map = folium.Map(location = [stops_sample.stop_lat.mean(), stops_sample.stop_lon.mean()], zoom_start = 12, width = 800, height = 600)

# %%
for i in range(0, len(stops_sample)):
    marker_color = ''
    if (stops_sample.wheelchair_boarding[i] == 1):
        marker_color = 'green'
    else:
        marker_color = 'red'
    folium.Marker(
                    location = [stops_sample.stop_lat[i], stops_sample.stop_lon[i]],
                    popup = stops_sample.stop_name[i],
                    tooltip = stops_sample.stop_code[i],
                    icon = folium.Icon(color = marker_color, prefix = 'fa', icon = 'bus')
                 ).add_to(stops_map)

# %%
fig = Figure(width = 800, height = 600)
fig.add_child(stops_map)
fig
