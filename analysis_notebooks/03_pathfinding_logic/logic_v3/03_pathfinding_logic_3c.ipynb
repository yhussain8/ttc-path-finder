# %% [markdown]
# # Pathfinding Model
# Objectives:
# - build a pathfinding model wrapped inside a function called `find_shortest_path`
# - this function should accept the user's starting and ending geocoordinates along with the current time
# - data has been preprocessed in a previous notebook and filtered only include regular weekday service; ie. stop times are for any given Monday to Friday

# %% [markdown]
# ---
# ## Import Modules & Data

# %%
import time
import numpy as np
import pandas as pd
import numexpr as ne
from datetime import timedelta as td

# %%
# %load_ext line_profiler

# %%
stops = pd.read_feather('data/model/stops.ftr')
schedule = pd.read_feather('data/model/schedule.ftr')

# %%
schedule.head(1)
# Out:
#     trip_id  route_short_name route_long_name  shape_id  \
# 0  42990004                10       VAN HORNE    886387
#
#                                trip_headsign  stop_sequence stop_time  \
# 0  EAST - 10 VAN HORNE towards VICTORIA PARK              1   7:00:29
#
#   stop_time_delta  stop_id  stop_code          stop_name   stop_lat   stop_lon
# 0 0 days 07:00:29    14155      14633  Don Mills Station  43.776222 -79.347048

# %%
stops.head(1)
# Out:
#    stop_id  stop_code                  stop_name   stop_lat   stop_lon
# 0      262        662  Danforth Rd at Kennedy Rd  43.714379 -79.260939

# %% [markdown]
# ---
# ## Define Helper Functions

# %%
def find_closest_stops(input_lat, input_lon):
    df = stops.loc[:, ['stop_id', 'stop_lat', 'stop_lon']]
    df['distance'] = ( abs(input_lat - df['stop_lat'])**2 + abs(input_lon - df['stop_lon'])**2 )**(1/2)
    df = df.sort_values(by = 'distance').reset_index(drop = True)
    return df

# %% [markdown]
# ---
# ## Define Functions

# %% [markdown]
# ## test arguments

# %%
test_start_time_delta = td(hours = 19)

# %% [markdown]
# ## find closest stop id

# %%
def find_closest_stop_id(input_lat, input_lon):
    df = stops.loc[:, ['stop_id', 'stop_lat', 'stop_lon']]
    df['distance'] = ( abs(input_lat - df['stop_lat'])**2 + abs(input_lon - df['stop_lon'])**2 )**(1/2)
    closest_stop_id = df.sort_values(by = 'distance').stop_id.values[0]
    return closest_stop_id

# %%
home = [43.76008911645013, -79.33181124795766]
test_stop_id = find_closest_stop_id(home[0], home[1])
test_stop_id
# Out:
# 917

# %% [markdown]
# ## walking speed

# %%
def walking_speed(stop_id_A = 917, stop_id_B = 9946, walk_time = 20 * 60):
    stop_A_lat = stops.loc[stops.stop_id == stop_id_A, 'stop_lat'].values[0]
    stop_A_lon = stops.loc[stops.stop_id == stop_id_A, 'stop_lon'].values[0]
    stop_B_lat = stops.loc[stops.stop_id == stop_id_B, 'stop_lat'].values[0]
    stop_B_lon = stops.loc[stops.stop_id == stop_id_B, 'stop_lon'].values[0]
    distance = abs(stop_B_lat - stop_A_lat) + abs(stop_B_lon - stop_A_lon)
    walking_speed = distance / walk_time
    return walking_speed

# %%
walking_speed()
# Out:
# 1.4267500000002541e-05

# %% [markdown]
# ## build shortest path

# %%
stops.head(1)
# Out:
#    stop_id  stop_code                  stop_name   stop_lat   stop_lon
# 0      262        662  Danforth Rd at Kennedy Rd  43.714379 -79.260939

# %%
stops_mini = stops.loc[:, ['stop_id', 'stop_lat', 'stop_lon']].copy().set_index('stop_id')
stops_mini.head(1)
# Out:
#           stop_lat   stop_lon
# stop_id
# 262      43.714379 -79.260939

# %%
def build_shortest_path(stops_df, start_stop_id, current_time_delta):
    start_stop_lat = stops_df.at[start_stop_id, 'stop_lat']
    start_stop_lon = stops_df.at[start_stop_id, 'stop_lon']
    walking_distance = abs(stops_df['stop_lat'] - start_stop_lat) + abs(stops_df['stop_lon'] - start_stop_lon)
    walking_time = round(walking_distance / walking_speed(), 0)
    stops_df['arrival_time_delta'] = current_time_delta + pd.to_timedelta(walking_time, 'seconds')
    stops_df['previous_stop'] = start_stop_id
    stops_df['previous_mode'] = 'W'
    stops_df['trip_id'] = None
    stops_df['visited'] = False
    return stops_df

# %%
test_shortest_path = build_shortest_path(stops_mini, test_stop_id, test_start_time_delta)
test_shortest_path.head(1)
# Out:
#           stop_lat   stop_lon arrival_time_delta  previous_stop previous_mode  \
# stop_id
# 262      43.714379 -79.260939    0 days 21:15:48            917             W
#
#         trip_id  visited
# stop_id
# 262        None    False

# %% [markdown]
# ## select unvisited stop with the earliest arrival

# %%
test_unvisited_stops = test_shortest_path.loc[test_shortest_path.visited == False]
test_unvisited_stops.head(1)
# Out:
#           stop_lat   stop_lon arrival_time_delta  previous_stop previous_mode  \
# stop_id
# 262      43.714379 -79.260939    0 days 21:15:48            917             W
#
#         trip_id  visited
# stop_id
# 262        None    False

# %%
test_current_stop_id = test_unvisited_stops.loc[test_unvisited_stops.arrival_time_delta == test_unvisited_stops.arrival_time_delta.min(), 'previous_stop'].values[0]
test_current_stop_id
# Out:
# 917

# %%
test_current_time_delta = test_shortest_path.at[test_current_stop_id, 'arrival_time_delta']
test_current_time_delta
# Out:
# Timedelta('0 days 19:00:00')

# %%
test_previous_mode = test_shortest_path.at[test_current_stop_id, 'previous_mode']
test_previous_mode
# Out:
# 'W'

# %% [markdown]
# ## build stop schedule

# %%
schedule.head(1)
# Out:
#     trip_id  route_short_name route_long_name  shape_id  \
# 0  42990004                10       VAN HORNE    886387
#
#                                trip_headsign  stop_sequence stop_time  \
# 0  EAST - 10 VAN HORNE towards VICTORIA PARK              1   7:00:29
#
#   stop_time_delta  stop_id  stop_code          stop_name   stop_lat   stop_lon
# 0 0 days 07:00:29    14155      14633  Don Mills Station  43.776222 -79.347048

# %%
schedule_mini = schedule.loc[:, ['trip_id', 'shape_id', 'stop_sequence', 'stop_id', 'stop_time_delta']].copy()
schedule_mini['trip_seq'] = (schedule_mini.trip_id.astype(str) + schedule_mini.stop_sequence.astype(str).str.zfill(2)).astype(int)
schedule_mini = schedule_mini.set_index('trip_seq')
schedule_mini = schedule_mini.sort_values(by = 'stop_time_delta')
schedule_mini['next_day'] = False
schedule_mini.head(1)
# Out:
#              trip_id  shape_id  stop_sequence  stop_id stop_time_delta  \
# trip_seq
# 4300346901  43003469    887148              1     8533 0 days 03:32:05
#
#             next_day
# trip_seq
# 4300346901     False

# %%
def build_stop_schedule(schedule_df, current_stop_id, current_time_delta):
    stop_id_values = schedule_df.stop_id.values
    stop_schedule = schedule_df[ne.evaluate('(stop_id_values == current_stop_id)')].copy()
    stop_schedule['next_day'] = np.where(stop_schedule.stop_time_delta < current_time_delta, True, False)
    stop_schedule['stop_time_delta'] = np.where(stop_schedule.next_day.values == True, stop_schedule.stop_time_delta + td(days = 1), stop_schedule.stop_time_delta)
    stop_schedule = pd.concat([stop_schedule[stop_schedule.next_day == False], stop_schedule[stop_schedule.next_day == True]])
    stop_schedule = stop_schedule.drop_duplicates(subset = 'shape_id')
    return stop_schedule

# %%
def build_table(df):
    
    select_condition = ((df.stop_id.values == 917) & (df.stop_time_delta > td(hours = 19)).values)
    df['select_trip'] = np.where(select_condition, df.trip_id.values, 0)
    trip_list = np.unique(df.select_trip.values)
    df['apply_trip'] = np.where(np.isin(df.trip_id.values, trip_list), df.trip_id.values, 0)

    df['select_shape'] = np.where(select_condition, df.shape_id.values, 0)
    shape_list = np.unique(df.shape_id.values)
    df['apply_shape'] = np.where(np.isin(df.shape_id.values, shape_list), df.shape_id.values, 0)

    df['select_sequence'] = np.where(select_condition, df.stop_sequence.values, 0)
    df2 = df.loc[select_condition, ['select_shape', 'select_sequence']].drop_duplicates()
    df['apply_sequence'] = df.apply_shape.map(df2.set_index('select_shape')['select_sequence'])

    compare_selection = ((df.apply_trip.values != 0) & (df.stop_sequence.values > df.apply_sequence.values))
    df['compare_sequence'] = np.where(compare_selection, True, False)
    df = df[compare_selection].drop_duplicates(subset = 'stop_id')

    return df

# %%
test_stop_schedule = build_stop_schedule(schedule_mini, test_current_stop_id, test_current_time_delta)
test_stop_schedule.head(1)
# Out:
#              trip_id  shape_id  stop_sequence  stop_id stop_time_delta  \
# trip_seq
# 4302716048  43027160    888274             48      917 0 days 19:00:42
#
#             next_day
# trip_seq
# 4302716048     False

# %%
test_stop_schedule
# Out:
#              trip_id  shape_id  stop_sequence  stop_id stop_time_delta  \
# trip_seq
# 4302716048  43027160    888274             48      917 0 days 19:00:42
# 4302930021  43029300    888390             21      917 0 days 19:02:47
# 4302715917  43027159    888280             17      917 0 days 19:07:45
# 4302721539  43027215    888281             39      917 0 days 20:20:45
# 4300560453  43005604    887271             53      917 1 days 02:52:20
#
#             next_day
# trip_seq
# 4302716048     False
# 4302930021     False
# 4302715917     False
# 4302721539     False
# 4300560453     False

# %%
# %lprun -f build_stop_schedule build_stop_schedule(schedule_mini, test_current_stop_id, test_current_time_delta)
# Out:
# Timer unit: 1e-06 s
#
# Total time: 0.050779 s
# File: <ipython-input-90-b41ec0588bad>
# Function: build_stop_schedule at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def build_stop_schedule(schedule_df, current_stop_id, current_time_delta):
#      2         1         88.0     88.0      0.2      stop_id_values = schedule_df.stop_id.values
#      3         1       5800.0   5800.0     11.4      stop_schedule = schedule_df[ne.evaluate('(stop_id_values == current_stop_id)')].copy()
#      4         1        780.0    780.0      1.5      stop_schedule['next_day'] = np.where(stop_schedule.stop_time_delta < current_time_delta, True, False)
#      5         1        986.0    986.0      1.9      stop_schedule['stop_time_delta'] = np.where(stop_schedule.next_day.values == True, stop_schedule.stop_time_delta + td(days = 1), stop_schedule.stop_time_delta)
#      6         1       7978.0   7978.0     15.7      stop_schedule = pd.concat([stop_schedule[stop_schedule.next_day == False], stop_schedule[stop_schedule.next_day == True]])
#      7         1      35145.0  35145.0     69.2      stop_schedule = stop_schedule.drop_duplicates(subset = 'shape_id')
#      8         1          2.0      2.0      0.0      return stop_schedule

# %%
# Do Not Delete!

def find_shortest_path(start_lat, start_lon, end_lat, end_lon, start_time_delta): 
    
    start_stop_id = find_closest_stop_id(start_lat, start_lon) # update parameters to include use of stops df
    shortest_path = build_shortest_path(stops_mini, start_stop_id, start_time_delta)
    
    for i in range(0, len(shortest_path)):
    # for i in range(0, 94):
                
        unvisited_stops = shortest_path.loc[shortest_path.visited == False]
        current_stop_id = unvisited_stops.loc[unvisited_stops.arrival_time_delta == unvisited_stops.arrival_time_delta.min(), 'previous_stop'].values[0]
        current_time_delta = shortest_path.at[next_visit_stop_id, 'arrival_time_delta']
        previous_mode = shortest_path.at[next_visit_stop_id, 'previous_mode']

        # *** IGNORE FOR NOW ***
        # if (previous_mode == 'T'):
            # shortest_path = update_walking_path(shortest_path, current_time_delta, current_stop_id)
        # **********************
        
        stop_schedule = build_stop_schedule(schedule_mini, current_stop_id, current_time_delta)
        upcoming_trip_stops = build_upcoming_trip_stops(stop_schedule)
        shortest_path = update_shortest_path(shortest_path, upcoming_trip_stops, current_time_delta, current_stop_id)
        
        shortest_path.loc[next_visit_stop_id, 'visited'] = True
        
    return shortest_path

# Notes
# include stops & schedule df (modified) as a parameter vs referencing it as a global variable?

# %% [markdown]
# #### can you filter a list of every stop with a trip that leaves from the current stop, and the associated earliest trip which will get me there
#
# #### create a set of all trips that will leave from the current stop (mark True); for each trip hardcode (even if duplicated) the next stop sequence in question (mark True all stop seq greater than this value); where both these values are True; select these into a further step to achieve perhaps same result without a for loop
#
# #### is there a way to get rid of the stops table all together and rely completely on the schedule df (even if data is duplicated)

# %% [markdown]
# ## build upcoming trip stops

# %%
test_stop_schedule
# Out:
#              trip_id  shape_id  stop_sequence  stop_id stop_time_delta  \
# trip_seq
# 4302716048  43027160    888274             48      917 0 days 19:00:42
# 4302930021  43029300    888390             21      917 0 days 19:02:47
# 4302715917  43027159    888280             17      917 0 days 19:07:45
# 4302721539  43027215    888281             39      917 0 days 20:20:45
# 4300560453  43005604    887271             53      917 1 days 02:52:20
#
#             next_day
# trip_seq
# 4302716048     False
# 4302930021     False
# 4302715917     False
# 4302721539     False
# 4300560453     False

# %%
## BREAK THE FOR LOOP VIA THE FUNCTION BEFORE
# First grab each required column in its entirety
# Ultimately create the filter to search schedule_mini for the requirements 
# (trips where trip_id is in stop_schedule and where stop_sequence is greater than the one on stop_schedule for the same trip in question)
# Then filter out duplicate records on stop_id
# END RESULT should be df with a list of unique stop_id values as the key and the associated earliest trip_id that will get you to that stop_id from the current_stop_id in question

# %%
def build_upcoming_trip_stops(stop_schedule):
    trip_id = stop_schedule.trip_id.values
    stop_sequence = stop_schedule.stop_sequence.values
    next_day = stop_schedule.next_day.values
    
    return upcoming_trip_stops

# %%
def build_upcoming_trip_stops(stop_schedule):
    upcoming_trip_stops = []
    for i in range(0, len(stop_schedule)):
        current_trip_id = stop_schedule['trip_id'].values[i]
        current_stop_sequence = stop_schedule['stop_sequence'].values[i]
        next_day = stop_schedule['next_day'].values[i]
        trip_id = schedule.trip_id.values
        stop_sequence = schedule.stop_sequence.values
        next_stops = schedule[ne.evaluate('(trip_id == current_trip_id) & (stop_sequence > current_stop_sequence)')].copy()
        if (next_day):
            next_stops.stop_time_delta = next_stops.stop_time_delta + td(days = 1)        
        upcoming_trip_stops.append(next_stops)
    upcoming_trip_stops = pd.concat(upcoming_trip_stops)
    upcoming_trip_stops = upcoming_trip_stops.sort_values(by = 'stop_time_delta').drop_duplicates(subset = 'stop_id', keep = 'first').reset_index(drop = True)
    return upcoming_trip_stops

# %%
test_upcoming_trip_stops = build_upcoming_trip_stops(test_stop_schedule)
test_upcoming_trip_stops.head(1)
# Out:
#     trip_id  route_short_name route_long_name  shape_id  \
# 0  43027160                95      YORK MILLS    888274
#
#                                      trip_headsign  stop_sequence stop_time  \
# 0  WEST - 95 YORK MILLS towards YORK MILLS STATION             49  19:01:15
#
#   stop_time_delta  stop_id  stop_code                stop_name   stop_lat  \
# 0 0 days 19:01:15     5191      11397  1200-1202 York Mills Rd  43.759132
#
#     stop_lon
# 0 -79.333893

# %%
test_upcoming_trip_stops
# Out:
#      trip_id  route_short_name     route_long_name  shape_id  \
# 0   43027160                95          YORK MILLS    888274
# 1   43027160                95          YORK MILLS    888274
# 2   43027160                95          YORK MILLS    888274
# 3   43027160                95          YORK MILLS    888274
# 4   43027160                95          YORK MILLS    888274
# 5   43027160                95          YORK MILLS    888274
# 6   43027160                95          YORK MILLS    888274
# 7   43027160                95          YORK MILLS    888274
# 8   43027160                95          YORK MILLS    888274
# 9   43027160                95          YORK MILLS    888274
# 10  43027160                95          YORK MILLS    888274
# 11  43027160                95          YORK MILLS    888274
# 12  43027160                95          YORK MILLS    888274
# 13  43027160                95          YORK MILLS    888274
# 14  43027160                95          YORK MILLS    888274
# 15  43027160                95          YORK MILLS    888274
# 16  43027160                95          YORK MILLS    888274
# 17  43027160                95          YORK MILLS    888274
# 18  43027160                95          YORK MILLS    888274
# 19  43027160                95          YORK MILLS    888274
# 20  43027160                95          YORK MILLS    888274
# 21  43027160                95          YORK MILLS    888274
# 22  43029300               995  YORK MILLS EXPRESS    888390
#
#                                         trip_headsign  stop_sequence  \
# 0     WEST - 95 YORK MILLS towards YORK MILLS STATION             49
# 1     WEST - 95 YORK MILLS towards YORK MILLS STATION             50
# 2     WEST - 95 YORK MILLS towards YORK MILLS STATION             51
# 3     WEST - 95 YORK MILLS towards YORK MILLS STATION             52
# 4     WEST - 95 YORK MILLS towards YORK MILLS STATION             53
# 5     WEST - 95 YORK MILLS towards YORK MILLS STATION             54
# 6     WEST - 95 YORK MILLS towards YORK MILLS STATION             55
# 7     WEST - 95 YORK MILLS towards YORK MILLS STATION             56
# 8     WEST - 95 YORK MILLS towards YORK MILLS STATION             57
# 9     WEST - 95 YORK MILLS towards YORK MILLS STATION             58
# 10    WEST - 95 YORK MILLS towards YORK MILLS STATION             59
# 11    WEST - 95 YORK MILLS towards YORK MILLS STATION             60
# 12    WEST - 95 YORK MILLS towards YORK MILLS STATION             61
# 13    WEST - 95 YORK MILLS towards YORK MILLS STATION             62
# 14    WEST - 95 YORK MILLS towards YORK MILLS STATION             63
# 15    WEST - 95 YORK MILLS towards YORK MILLS STATION             64
# 16    WEST - 95 YORK MILLS towards YORK MILLS STATION             65
# 17    WEST - 95 YORK MILLS towards YORK MILLS STATION             66
# 18    WEST - 95 YORK MILLS towards YORK MILLS STATION             67
# 19    WEST - 95 YORK MILLS towards YORK MILLS STATION             68
# 20    WEST - 95 YORK MILLS towards YORK MILLS STATION             69
# 21    WEST - 95 YORK MILLS towards YORK MILLS STATION             70
# 22  WEST - 995 YORK MILLS EXPRESS towards YORK MIL...             26
#
#    stop_time stop_time_delta  stop_id  stop_code  \
# 0   19:01:15 0 days 19:01:15     5191      11397
# 1   19:02:24 0 days 19:02:24     7238       9079
# 2   19:02:46 0 days 19:02:46     5738       9087
# 3   19:03:52 0 days 19:03:52     9834       9071
# 4   19:05:13 0 days 19:05:13     6330      10605
# 5   19:06:05 0 days 19:06:05      916       9078
# 6   19:07:58 0 days 19:07:58     9974      13469
# 7   19:09:09 0 days 19:09:09      944       9077
# 8   19:10:02 0 days 19:10:02     1509       7466
# 9   19:11:03 0 days 19:11:03     9959       7464
# 10  19:11:57 0 days 19:11:57     6998       7473
# 11  19:12:44 0 days 19:12:44    10010       7469
# 12  19:14:07 0 days 19:14:07     1356       9069
# 13  19:14:55 0 days 19:14:55     8815       3258
# 14  19:15:26 0 days 19:15:26     6389       3253
# 15  19:16:01 0 days 19:16:01     2255       3255
# 16  19:16:23 0 days 19:16:23     1697       7474
# 17  19:16:57 0 days 19:16:57     1852       9074
# 18  19:17:22 0 days 19:17:22     9572       3265
# 19  19:18:03 0 days 19:18:03     6062      11334
# 20  19:18:14 0 days 19:18:14      919       9906
# 21  19:18:51 0 days 19:18:51    24357      15974
# 22  19:20:57 0 days 19:20:57    24358      15975
#
#                                    stop_name   stop_lat   stop_lon
# 0                    1200-1202 York Mills Rd  43.759132 -79.333893
# 1            York Mills Rd at Lochinvar Cres  43.757624 -79.339319
# 2              York Mills Rd at Valentine Dr  43.757207 -79.341181
# 3              York Mills Rd at Don Mills Rd  43.756053 -79.346600
# 4                          900 York Mills Rd  43.755228 -79.350256
# 5      York Mills Rd at Lesmill Rd West Side  43.754734 -79.352534
# 6              York Mills Rd at Scarsdale Rd  43.753660 -79.357427
# 7       York Mills Rd at Leslie St West Side  43.753001 -79.360766
# 8         York Mills Rd at Banbury Rd (East)  43.752639 -79.365268
# 9         York Mills Rd at Banbury Rd (West)  43.751639 -79.370302
# 10             York Mills Rd at Sandfield Rd  43.750689 -79.374746
# 11              York Mills Rd at Harrison Rd  43.749891 -79.378669
# 12    York Mills Rd at Bayview Ave West Side  43.748013 -79.384820
# 13                 York Mills Rd at Fenn Ave  43.747131 -79.388881
# 14            York Mills Rd at Birchwood Ave  43.746570 -79.391504
# 15  York Mills Rd at Cedarwood Ave West Side  43.745953 -79.394494
# 16      York Mills Rd at Upper Highland Cres  43.745541 -79.396356
# 17             York Mills Rd at Old Yonge St  43.744926 -79.399283
# 18            York Mills Rd at York Ridge Rd  43.744470 -79.401416
# 19        York Mills Rd at Old York Mills Rd  43.744461 -79.404964
# 20                 York Mills Rd at Yonge St  43.744417 -79.405968
# 21             York Mills Temporary Bus Loop  43.744303 -79.407324
# 22             York Mills Temporary Bus Loop  43.744536 -79.407150

# %%
# %lprun -f build_upcoming_trip_stops build_upcoming_trip_stops(test_stop_schedule)
# Out:
# Timer unit: 1e-06 s
#
# Total time: 0.038005 s
# File: <ipython-input-97-4ec59065ae06>
# Function: build_upcoming_trip_stops at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def build_upcoming_trip_stops(stop_schedule):
#      2         1          2.0      2.0      0.0      upcoming_trip_stops = []
#      3         6         18.0      3.0      0.0      for i in range(0, len(stop_schedule)):
#      4         5        180.0     36.0      0.5          current_trip_id = stop_schedule['trip_id'].values[i]
#      5         5         91.0     18.2      0.2          current_stop_sequence = stop_schedule['stop_sequence'].values[i]
#      6         5         80.0     16.0      0.2          next_day = stop_schedule['next_day'].values[i]
#      7         5        166.0     33.2      0.4          trip_id = schedule.trip_id.values
#      8         5        128.0     25.6      0.3          stop_sequence = schedule.stop_sequence.values
#      9         5      23443.0   4688.6     61.7          next_stops = schedule[ne.evaluate('(trip_id == current_trip_id) & (stop_sequence > current_stop_sequence)')].copy()
#     10         5         10.0      2.0      0.0          if (next_day):
#     11                                                       next_stops.stop_time_delta = next_stops.stop_time_delta + td(days = 1)
#     12         5          5.0      1.0      0.0          upcoming_trip_stops.append(next_stops)
#     13         1       2855.0   2855.0      7.5      upcoming_trip_stops = pd.concat(upcoming_trip_stops)
#     14         1      11025.0  11025.0     29.0      upcoming_trip_stops = upcoming_trip_stops.sort_values(by = 'stop_time_delta').drop_duplicates(subset = 'stop_id', keep = 'first').reset_index(drop = True)
#     15         1          2.0      2.0      0.0      return upcoming_trip_stops

# %%
# %%timeit
build_upcoming_trip_stops(test_stop_schedule)
# Out:
# 28.1 ms ± 1.47 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ## update shortest path

# %%
def update_shortest_path(shortest_path, upcoming_trip_stops, current_time_delta, visiting_stop_id):
    
    for i in range(0, len(upcoming_trip_stops)):
        current_stop_id = upcoming_trip_stops.loc[i, 'stop_id']
        current_stop_time_delta = upcoming_trip_stops.loc[i, 'stop_time_delta']
        current_trip_id = upcoming_trip_stops.loc[i, 'trip_id']
        current_arrival_time = shortest_path.loc[shortest_path.stop_id == current_stop_id, 'arrival_time_delta'].values[0]
        
        if (current_arrival_time > current_stop_time_delta):
            shortest_path.loc[shortest_path.stop_id == current_stop_id, 'arrival_time_delta'] = current_stop_time_delta
            shortest_path.loc[shortest_path.stop_id == current_stop_id, 'previous_stop'] = visiting_stop_id
            shortest_path.loc[shortest_path.stop_id == current_stop_id, 'previous_mode'] = 'T'
            shortest_path.loc[shortest_path.stop_id == current_stop_id, 'trip_id'] = current_trip_id
            
    shortest_path = shortest_path.sort_values(by = 'arrival_time_delta').reset_index(drop = True)
    shortest_path.loc[shortest_path.stop_id == visiting_stop_id, 'visited'] = True
    
    return shortest_path

# %%
input_shortest_path
# Out:
#       stop_id  stop_code                                          stop_name  \
# 0         917       9083     York Mills Rd at Sandover Dr (1222 York Mills)
# 1        8081       9088         York Mills Rd at Valley Woods Rd East Side
# 2       10256      11533                                113 Valley Woods Rd
# 3        6913      11527                   Valley Woods Rd at York Mills Rd
# 4        5191      11397                            1200-1202 York Mills Rd
# ...       ...        ...                                                ...
# 9414     4305       1632             The West Mall at Sherway Dr North Side
# 9415     7093       1631  The West Mall at Trillium Health Centre (North...
# 9416      880       1633  The West Mall at Sherway Dr (Trillium Health C...
# 9417      477       4435                                   Long Branch Loop
# 9418     1750       5511                                   Long Branch Loop
#
#        stop_lat   stop_lon arrival_time_delta  previous_stop previous_mode  \
# 0     43.759813 -79.331751    0 days 19:00:00            917             W
# 1     43.759595 -79.332036    0 days 19:00:35            917             W
# 2     43.758960 -79.332778    0 days 19:02:12            917             W
# 3     43.758994 -79.333070    0 days 19:02:30            917             W
# 4     43.759132 -79.333893    0 days 19:03:18            917             W
# ...         ...        ...                ...            ...           ...
# 9414  43.609781 -79.560638    1 days 02:22:38            917             W
# 9415  43.610381 -79.561480    1 days 02:22:55            917             W
# 9416  43.609464 -79.560579    1 days 02:22:56            917             W
# 9417  43.592111 -79.543700    1 days 02:23:29            917             W
# 9418  43.591811 -79.544124    1 days 02:24:20            917             W
#
#      trip_id  visited
# 0       None    False
# 1       None    False
# 2       None    False
# 3       None    False
# 4       None    False
# ...      ...      ...
# 9414    None    False
# 9415    None    False
# 9416    None    False
# 9417    None    False
# 9418    None    False
#
# [9419 rows x 10 columns]

# %%
input_shortest_path.set_index('stop_id')
# Out:
#          stop_code                                          stop_name  \
# stop_id
# 917           9083     York Mills Rd at Sandover Dr (1222 York Mills)
# 8081          9088         York Mills Rd at Valley Woods Rd East Side
# 10256        11533                                113 Valley Woods Rd
# 6913         11527                   Valley Woods Rd at York Mills Rd
# 5191         11397                            1200-1202 York Mills Rd
# ...            ...                                                ...
# 4305          1632             The West Mall at Sherway Dr North Side
# 7093          1631  The West Mall at Trillium Health Centre (North...
# 880           1633  The West Mall at Sherway Dr (Trillium Health C...
# 477           4435                                   Long Branch Loop
# 1750          5511                                   Long Branch Loop
#
#           stop_lat   stop_lon arrival_time_delta  previous_stop previous_mode  \
# stop_id
# 917      43.759813 -79.331751    0 days 19:00:00            917             W
# 8081     43.759595 -79.332036    0 days 19:00:35            917             W
# 10256    43.758960 -79.332778    0 days 19:02:12            917             W
# 6913     43.758994 -79.333070    0 days 19:02:30            917             W
# 5191     43.759132 -79.333893    0 days 19:03:18            917             W
# ...            ...        ...                ...            ...           ...
# 4305     43.609781 -79.560638    1 days 02:22:38            917             W
# 7093     43.610381 -79.561480    1 days 02:22:55            917             W
# 880      43.609464 -79.560579    1 days 02:22:56            917             W
# 477      43.592111 -79.543700    1 days 02:23:29            917             W
# 1750     43.591811 -79.544124    1 days 02:24:20            917             W
#
#         trip_id  visited
# stop_id
# 917        None    False
# 8081       None    False
# 10256      None    False
# 6913       None    False
# 5191       None    False
# ...         ...      ...
# 4305       None    False
# 7093       None    False
# 880        None    False
# 477        None    False
# 1750       None    False
#
# [9419 rows x 9 columns]

# %%
ex_s_path = pd.merge(input_shortest_path, upcoming_trip_stops, 'left', 'stop_id', suffixes = ('', '_uts'))

# %%
ex_s_path.T
# Out:
#                                                               0     \
# stop_id                                                        917
# stop_code                                                     9083
# stop_name           York Mills Rd at Sandover Dr (1222 York Mills)
# stop_lat                                                 43.759813
# stop_lon                                                -79.331751
# arrival_time_delta                                 0 days 19:00:00
# previous_stop                                                  917
# previous_mode                                                    W
# trip_id                                                       None
# visited                                                      False
# trip_id_uts                                                    NaN
# route_short_name                                               NaN
# route_long_name                                                NaN
# shape_id                                                       NaN
# trip_headsign                                                  NaN
# stop_sequence                                                  NaN
# stop_time                                                      NaN
# stop_time_delta                                                NaT
# stop_code_uts                                                  NaN
# stop_name_uts                                                  NaN
# stop_lat_uts                                                   NaN
# stop_lon_uts                                                   NaN
#
#                                                           1     \
# stop_id                                                   8081
# stop_code                                                 9088
# stop_name           York Mills Rd at Valley Woods Rd East Side
# stop_lat                                             43.759595
# stop_lon                                            -79.332036
# arrival_time_delta                             0 days 19:00:35
# previous_stop                                              917
# previous_mode                                                W
# trip_id                                                   None
# visited                                                  False
# trip_id_uts                                                NaN
# route_short_name                                           NaN
# route_long_name                                            NaN
# shape_id                                                   NaN
# trip_headsign                                              NaN
# stop_sequence                                              NaN
# stop_time                                                  NaN
# stop_time_delta                                            NaT
# stop_code_uts                                              NaN
# stop_name_uts                                              NaN
# stop_lat_uts                                               NaN
# stop_lon_uts                                               NaN
#
#                                    2                                 3     \
# stop_id                           10256                              6913
# stop_code                         11533                             11527
# stop_name           113 Valley Woods Rd  Valley Woods Rd at York Mills Rd
# stop_lat                       43.75896                         43.758994
# stop_lon                     -79.332778                         -79.33307
# arrival_time_delta      0 days 19:02:12                   0 days 19:02:30
# previous_stop                       917                               917
# previous_mode                         W                                 W
# trip_id                            None                              None
# visited                           False                             False
# trip_id_uts                         NaN                               NaN
# route_short_name                    NaN                               NaN
# route_long_name                     NaN                               NaN
# shape_id                            NaN                               NaN
# trip_headsign                       NaN                               NaN
# stop_sequence                       NaN                               NaN
# stop_time                           NaN                               NaN
# stop_time_delta                     NaT                               NaT
# stop_code_uts                       NaN                               NaN
# stop_name_uts                       NaN                               NaN
# stop_lat_uts                        NaN                               NaN
# stop_lon_uts                        NaN                               NaN
#
#                                                                4     \
# stop_id                                                        5191
# stop_code                                                     11397
# stop_name                                   1200-1202 York Mills Rd
# stop_lat                                                  43.759132
# stop_lon                                                 -79.333893
# arrival_time_delta                                  0 days 19:03:18
# previous_stop                                                   917
# previous_mode                                                     W
# trip_id                                                        None
# visited                                                       False
# trip_id_uts                                              43027160.0
# route_short_name                                               95.0
# route_long_name                                          YORK MILLS
# shape_id                                                   888274.0
# trip_headsign       WEST - 95 YORK MILLS towards YORK MILLS STATION
# stop_sequence                                                  49.0
# stop_time                                                  19:01:15
# stop_time_delta                                     0 days 19:01:15
# stop_code_uts                                               11397.0
# stop_name_uts                               1200-1202 York Mills Rd
# stop_lat_uts                                              43.759132
# stop_lon_uts                                             -79.333893
#
#                                            5                            6     \
# stop_id                                    4880                         6061
# stop_code                                  9072                         9073
# stop_name           York Mills Rd at Fenside Dr  York Mills Rd at Fenside Dr
# stop_lat                              43.760561                    43.760782
# stop_lon                             -79.327819                   -79.327546
# arrival_time_delta              0 days 19:05:28              0 days 19:06:03
# previous_stop                               917                          917
# previous_mode                                 W                            W
# trip_id                                    None                         None
# visited                                   False                        False
# trip_id_uts                                 NaN                          NaN
# route_short_name                            NaN                          NaN
# route_long_name                             NaN                          NaN
# shape_id                                    NaN                          NaN
# trip_headsign                               NaN                          NaN
# stop_sequence                               NaN                          NaN
# stop_time                                   NaN                          NaN
# stop_time_delta                             NaT                          NaT
# stop_code_uts                               NaN                          NaN
# stop_name_uts                               NaN                          NaN
# stop_lat_uts                                NaN                          NaN
# stop_lon_uts                                NaN                          NaN
#
#                                                      7     \
# stop_id                                              6223
# stop_code                                           13959
# stop_name           Lynedock Cres at Fenside Dr East Side
# stop_lat                                        43.761865
# stop_lon                                       -79.328158
# arrival_time_delta                        0 days 19:06:36
# previous_stop                                         917
# previous_mode                                           W
# trip_id                                              None
# visited                                             False
# trip_id_uts                                           NaN
# route_short_name                                      NaN
# route_long_name                                       NaN
# shape_id                                              NaN
# trip_headsign                                         NaN
# stop_sequence                                         NaN
# stop_time                                             NaN
# stop_time_delta                                       NaT
# stop_code_uts                                         NaN
# stop_name_uts                                         NaN
# stop_lat_uts                                          NaN
# stop_lon_uts                                          NaN
#
#                                            8                           9     \
# stop_id                                   10406                        6235
# stop_code                                 11532                       13958
# stop_name           Opposite 44 Valley Woods Rd  Fenside Dr at Slidell Cres
# stop_lat                              43.755229                    43.76331
# stop_lon                             -79.333336                  -79.329061
# arrival_time_delta              0 days 19:07:12             0 days 19:07:14
# previous_stop                               917                         917
# previous_mode                                 W                           W
# trip_id                                    None                        None
# visited                                   False                       False
# trip_id_uts                                 NaN                         NaN
# route_short_name                            NaN                         NaN
# route_long_name                             NaN                         NaN
# shape_id                                    NaN                         NaN
# trip_headsign                               NaN                         NaN
# stop_sequence                               NaN                         NaN
# stop_time                                   NaN                         NaN
# stop_time_delta                             NaT                         NaT
# stop_code_uts                               NaN                         NaN
# stop_name_uts                               NaN                         NaN
# stop_lat_uts                                NaN                         NaN
# stop_lon_uts                                NaN                         NaN
#
#                     ...                                     9409  \
# stop_id             ...                                     6979
# stop_code           ...                                     1271
# stop_name           ...  Markland Dr at Cherry Post Cres (North)
# stop_lat            ...                                43.633138
# stop_lon            ...                               -79.582671
# arrival_time_delta  ...                          1 days 02:21:05
# previous_stop       ...                                      917
# previous_mode       ...                                        W
# trip_id             ...                                     None
# visited             ...                                    False
# trip_id_uts         ...                                      NaN
# route_short_name    ...                                      NaN
# route_long_name     ...                                      NaN
# shape_id            ...                                      NaN
# trip_headsign       ...                                      NaN
# stop_sequence       ...                                      NaN
# stop_time           ...                                      NaN
# stop_time_delta     ...                                      NaT
# stop_code_uts       ...                                      NaN
# stop_name_uts       ...                                      NaN
# stop_lat_uts        ...                                      NaN
# stop_lon_uts        ...                                      NaN
#
#                                               9410  \
# stop_id                                       9397
# stop_code                                     1638
# stop_name           The West Mall at The Queensway
# stop_lat                                 43.611806
# stop_lon                                -79.562012
# arrival_time_delta                 1 days 02:21:53
# previous_stop                                  917
# previous_mode                                    W
# trip_id                                       None
# visited                                      False
# trip_id_uts                                    NaN
# route_short_name                               NaN
# route_long_name                                NaN
# shape_id                                       NaN
# trip_headsign                                  NaN
# stop_sequence                                  NaN
# stop_time                                      NaN
# stop_time_delta                                NaT
# stop_code_uts                                  NaN
# stop_name_uts                                  NaN
# stop_lat_uts                                   NaN
# stop_lon_uts                                   NaN
#
#                                                                  9411  \
# stop_id                                                          4588
# stop_code                                                        3169
# stop_name           The West Mall at Sherway Dr (Trillium Health C...
# stop_lat                                                    43.609417
# stop_lon                                                   -79.559813
# arrival_time_delta                                    1 days 02:22:06
# previous_stop                                                     917
# previous_mode                                                       W
# trip_id                                                          None
# visited                                                         False
# trip_id_uts                                                       NaN
# route_short_name                                                  NaN
# route_long_name                                                   NaN
# shape_id                                                          NaN
# trip_headsign                                                     NaN
# stop_sequence                                                     NaN
# stop_time                                                         NaN
# stop_time_delta                                                   NaT
# stop_code_uts                                                     NaN
# stop_name_uts                                                     NaN
# stop_lat_uts                                                      NaN
# stop_lon_uts                                                      NaN
#
#                                                      9412  \
# stop_id                                               881
# stop_code                                           11119
# stop_name           The West Mall at Queensway South Side
# stop_lat                                         43.61175
# stop_lon                                       -79.562334
# arrival_time_delta                        1 days 02:22:19
# previous_stop                                         917
# previous_mode                                           W
# trip_id                                              None
# visited                                             False
# trip_id_uts                                           NaN
# route_short_name                                      NaN
# route_long_name                                       NaN
# shape_id                                              NaN
# trip_headsign                                         NaN
# stop_sequence                                         NaN
# stop_time                                             NaN
# stop_time_delta                                       NaT
# stop_code_uts                                         NaN
# stop_name_uts                                         NaN
# stop_lat_uts                                          NaN
# stop_lon_uts                                          NaN
#
#                                                               9413  \
# stop_id                                                       1523
# stop_code                                                     1269
# stop_name           Markland Dr (West) at Bloor St West North Side
# stop_lat                                                 43.629667
# stop_lon                                                -79.580248
# arrival_time_delta                                 1 days 02:22:19
# previous_stop                                                  917
# previous_mode                                                    W
# trip_id                                                       None
# visited                                                      False
# trip_id_uts                                                    NaN
# route_short_name                                               NaN
# route_long_name                                                NaN
# shape_id                                                       NaN
# trip_headsign                                                  NaN
# stop_sequence                                                  NaN
# stop_time                                                      NaN
# stop_time_delta                                                NaT
# stop_code_uts                                                  NaN
# stop_name_uts                                                  NaN
# stop_lat_uts                                                   NaN
# stop_lon_uts                                                   NaN
#
#                                                       9414  \
# stop_id                                               4305
# stop_code                                             1632
# stop_name           The West Mall at Sherway Dr North Side
# stop_lat                                         43.609781
# stop_lon                                        -79.560638
# arrival_time_delta                         1 days 02:22:38
# previous_stop                                          917
# previous_mode                                            W
# trip_id                                               None
# visited                                              False
# trip_id_uts                                            NaN
# route_short_name                                       NaN
# route_long_name                                        NaN
# shape_id                                               NaN
# trip_headsign                                          NaN
# stop_sequence                                          NaN
# stop_time                                              NaN
# stop_time_delta                                        NaT
# stop_code_uts                                          NaN
# stop_name_uts                                          NaN
# stop_lat_uts                                           NaN
# stop_lon_uts                                           NaN
#
#                                                                  9415  \
# stop_id                                                          7093
# stop_code                                                        1631
# stop_name           The West Mall at Trillium Health Centre (North...
# stop_lat                                                    43.610381
# stop_lon                                                    -79.56148
# arrival_time_delta                                    1 days 02:22:55
# previous_stop                                                     917
# previous_mode                                                       W
# trip_id                                                          None
# visited                                                         False
# trip_id_uts                                                       NaN
# route_short_name                                                  NaN
# route_long_name                                                   NaN
# shape_id                                                          NaN
# trip_headsign                                                     NaN
# stop_sequence                                                     NaN
# stop_time                                                         NaN
# stop_time_delta                                                   NaT
# stop_code_uts                                                     NaN
# stop_name_uts                                                     NaN
# stop_lat_uts                                                      NaN
# stop_lon_uts                                                      NaN
#
#                                                                  9416  \
# stop_id                                                           880
# stop_code                                                        1633
# stop_name           The West Mall at Sherway Dr (Trillium Health C...
# stop_lat                                                    43.609464
# stop_lon                                                   -79.560579
# arrival_time_delta                                    1 days 02:22:56
# previous_stop                                                     917
# previous_mode                                                       W
# trip_id                                                          None
# visited                                                         False
# trip_id_uts                                                       NaN
# route_short_name                                                  NaN
# route_long_name                                                   NaN
# shape_id                                                          NaN
# trip_headsign                                                     NaN
# stop_sequence                                                     NaN
# stop_time                                                         NaN
# stop_time_delta                                                   NaT
# stop_code_uts                                                     NaN
# stop_name_uts                                                     NaN
# stop_lat_uts                                                      NaN
# stop_lon_uts                                                      NaN
#
#                                 9417              9418
# stop_id                          477              1750
# stop_code                       4435              5511
# stop_name           Long Branch Loop  Long Branch Loop
# stop_lat                   43.592111         43.591811
# stop_lon                    -79.5437        -79.544124
# arrival_time_delta   1 days 02:23:29   1 days 02:24:20
# previous_stop                    917               917
# previous_mode                      W                 W
# trip_id                         None              None
# visited                        False             False
# trip_id_uts                      NaN               NaN
# route_short_name                 NaN               NaN
# route_long_name                  NaN               NaN
# shape_id                         NaN               NaN
# trip_headsign                    NaN               NaN
# stop_sequence                    NaN               NaN
# stop_time                        NaN               NaN
# stop_time_delta                  NaT               NaT
# stop_code_uts                    NaN               NaN
# stop_name_uts                    NaN               NaN
# stop_lat_uts                     NaN               NaN
# stop_lon_uts                     NaN               NaN
#
# [22 rows x 9419 columns]

# %%
def update_shortest_path(s_path, upcoming_trip_stops, current_time_delta, visiting_stop_id):
    
    #s_path = s_path.set_index('stop_id')
    #upcoming_trip_stops = upcoming_trip_stops.set_index('stop_id')
    
    s_path = s_path.join(upcoming_trip_stops, on = 'stop_id', how = 'left', rsuffix = '_uts')
    
    s_path.previous_stop = np.where(
        s_path.stop_time_delta.values < s_path.arrival_time_delta.values,
        visiting_stop_id,
        s_path.previous_stop.values
    )
    s_path.previous_mode = np.where(
        s_path.stop_time_delta.values < s_path.arrival_time_delta.values,
        'T',
        s_path.previous_mode.values
    )
    s_path.trip_id = np.where(
        s_path.stop_time_delta.values < s_path.arrival_time_delta.values,
        s_path.trip_id_uts.values,
        s_path.trip_id.values
    )
    s_path.arrival_time_delta = np.where(
        s_path.stop_time_delta.values < s_path.arrival_time_delta.values,
        s_path.stop_time_delta.values,
        s_path.arrival_time_delta.values
    )
            
    s_path.loc[visiting_stop_id, 'visited'] = True
    s_path = s_path.sort_values(by = 'arrival_time_delta').reset_index(drop = False)
    
    return s_path.loc[:, 'stop_id':'visited']

# %%
input_shortest_path.set_index('stop_id', inplace = True)
upcoming_trip_stops.set_index('stop_id', inplace = True)

# %%
input_shortest_path.head(3)
# Out:
#          stop_code                                       stop_name   stop_lat  \
# stop_id
# 917           9083  York Mills Rd at Sandover Dr (1222 York Mills)  43.759813
# 8081          9088      York Mills Rd at Valley Woods Rd East Side  43.759595
# 10256        11533                             113 Valley Woods Rd  43.758960
#
#           stop_lon arrival_time_delta  previous_stop previous_mode trip_id  \
# stop_id
# 917     -79.331751    0 days 19:00:00            917             W    None
# 8081    -79.332036    0 days 19:00:35            917             W    None
# 10256   -79.332778    0 days 19:02:12            917             W    None
#
#          visited
# stop_id
# 917        False
# 8081       False
# 10256      False

# %%
upcoming_trip_stops.head(3)
# Out:
#           trip_id  route_short_name route_long_name  shape_id  \
# stop_id
# 5191     43027160                95      YORK MILLS    888274
# 7238     43027160                95      YORK MILLS    888274
# 5738     43027160                95      YORK MILLS    888274
#
#                                            trip_headsign  stop_sequence  \
# stop_id
# 5191     WEST - 95 YORK MILLS towards YORK MILLS STATION             49
# 7238     WEST - 95 YORK MILLS towards YORK MILLS STATION             50
# 5738     WEST - 95 YORK MILLS towards YORK MILLS STATION             51
#
#         stop_time stop_time_delta  stop_code                        stop_name  \
# stop_id
# 5191     19:01:15 0 days 19:01:15      11397          1200-1202 York Mills Rd
# 7238     19:02:24 0 days 19:02:24       9079  York Mills Rd at Lochinvar Cres
# 5738     19:02:46 0 days 19:02:46       9087    York Mills Rd at Valentine Dr
#
#           stop_lat   stop_lon
# stop_id
# 5191     43.759132 -79.333893
# 7238     43.757624 -79.339319
# 5738     43.757207 -79.341181

# %%
input_shortest_path = build_shortest_path(917, td(hours = 19))
stop_schedule = build_stop_schedule(917, td(hours = 19))
upcoming_trip_stops = build_upcoming_trip_stops(stop_schedule)

# %%
# %%time
s_path = update_shortest_path(input_shortest_path, upcoming_trip_stops, td(hours = 19), 917)
# Out:
# CPU times: user 22.9 ms, sys: 3.63 ms, total: 26.5 ms
# Wall time: 25.4 ms

# %%
# %%timeit
s_path = update_shortest_path(input_shortest_path, upcoming_trip_stops, td(hours = 19), 917)
# Out:
# 15.9 ms ± 457 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
s_path

# %%
s_path
# Out:
#       stop_id  stop_code                                          stop_name  \
# 0         917       9083     York Mills Rd at Sandover Dr (1222 York Mills)
# 1        8081       9088         York Mills Rd at Valley Woods Rd East Side
# 2        5191      11397                            1200-1202 York Mills Rd
# 3       10256      11533                                113 Valley Woods Rd
# 4        7238       9079                    York Mills Rd at Lochinvar Cres
# ...       ...        ...                                                ...
# 9414     4305       1632             The West Mall at Sherway Dr North Side
# 9415     7093       1631  The West Mall at Trillium Health Centre (North...
# 9416      880       1633  The West Mall at Sherway Dr (Trillium Health C...
# 9417      477       4435                                   Long Branch Loop
# 9418     1750       5511                                   Long Branch Loop
#
#        stop_lat   stop_lon arrival_time_delta  previous_stop previous_mode  \
# 0     43.759813 -79.331751    0 days 19:00:00            917             W
# 1     43.759595 -79.332036    0 days 19:00:35            917             W
# 2     43.759132 -79.333893    0 days 19:01:15            917             T
# 3     43.758960 -79.332778    0 days 19:02:12            917             W
# 4     43.757624 -79.339319    0 days 19:02:24            917             T
# ...         ...        ...                ...            ...           ...
# 9414  43.609781 -79.560638    1 days 02:22:38            917             W
# 9415  43.610381 -79.561480    1 days 02:22:55            917             W
# 9416  43.609464 -79.560579    1 days 02:22:56            917             W
# 9417  43.592111 -79.543700    1 days 02:23:29            917             W
# 9418  43.591811 -79.544124    1 days 02:24:20            917             W
#
#          trip_id  visited
# 0           None     True
# 1           None    False
# 2     43027160.0    False
# 3           None    False
# 4     43027160.0    False
# ...          ...      ...
# 9414        None    False
# 9415        None    False
# 9416        None    False
# 9417        None    False
# 9418        None    False
#
# [9419 rows x 10 columns]

# %%
s_path
# Out:
#    stop_code                                       stop_name   stop_lat  \
# 0       9083  York Mills Rd at Sandover Dr (1222 York Mills)  43.759813
# 1       9088      York Mills Rd at Valley Woods Rd East Side  43.759595
# 2      11397                         1200-1202 York Mills Rd  43.759132
# 3      11533                             113 Valley Woods Rd  43.758960
# 4       9079                 York Mills Rd at Lochinvar Cres  43.757624
# 5      11527                Valley Woods Rd at York Mills Rd  43.758994
# 6       9087                   York Mills Rd at Valentine Dr  43.757207
# 7       9071                   York Mills Rd at Don Mills Rd  43.756053
# 8      10605                               900 York Mills Rd  43.755228
#
#     stop_lon arrival_time_delta  previous_stop previous_mode     trip_id  \
# 0 -79.331751    0 days 19:00:00            917             W        None
# 1 -79.332036    0 days 19:00:35            917             W        None
# 2 -79.333893    0 days 19:01:15            917             T  43027160.0
# 3 -79.332778    0 days 19:02:12            917             W        None
# 4 -79.339319    0 days 19:02:24            917             T  43027160.0
# 5 -79.333070    0 days 19:02:30            917             W        None
# 6 -79.341181    0 days 19:02:46            917             T  43027160.0
# 7 -79.346600    0 days 19:03:52            917             T  43027160.0
# 8 -79.350256    0 days 19:05:13            917             T  43027160.0
#
#    visited  trip_id_uts  ...  route_long_name  shape_id  \
# 0     True          NaN  ...              NaN       NaN
# 1    False          NaN  ...              NaN       NaN
# 2    False   43027160.0  ...       YORK MILLS  888274.0
# 3    False          NaN  ...              NaN       NaN
# 4    False   43027160.0  ...       YORK MILLS  888274.0
# 5    False          NaN  ...              NaN       NaN
# 6    False   43027160.0  ...       YORK MILLS  888274.0
# 7    False   43027160.0  ...       YORK MILLS  888274.0
# 8    False   43027160.0  ...       YORK MILLS  888274.0
#
#                                      trip_headsign stop_sequence  stop_time  \
# 0                                              NaN           NaN        NaN
# 1                                              NaN           NaN        NaN
# 2  WEST - 95 YORK MILLS towards YORK MILLS STATION          49.0   19:01:15
# 3                                              NaN           NaN        NaN
# 4  WEST - 95 YORK MILLS towards YORK MILLS STATION          50.0   19:02:24
# 5                                              NaN           NaN        NaN
# 6  WEST - 95 YORK MILLS towards YORK MILLS STATION          51.0   19:02:46
# 7  WEST - 95 YORK MILLS towards YORK MILLS STATION          52.0   19:03:52
# 8  WEST - 95 YORK MILLS towards YORK MILLS STATION          53.0   19:05:13
#
#   stop_time_delta stop_code_uts                    stop_name_uts stop_lat_uts  \
# 0             NaT           NaN                              NaN          NaN
# 1             NaT           NaN                              NaN          NaN
# 2 0 days 19:01:15       11397.0          1200-1202 York Mills Rd    43.759132
# 3             NaT           NaN                              NaN          NaN
# 4 0 days 19:02:24        9079.0  York Mills Rd at Lochinvar Cres    43.757624
# 5             NaT           NaN                              NaN          NaN
# 6 0 days 19:02:46        9087.0    York Mills Rd at Valentine Dr    43.757207
# 7 0 days 19:03:52        9071.0    York Mills Rd at Don Mills Rd    43.756053
# 8 0 days 19:05:13       10605.0                900 York Mills Rd    43.755228
#
#    stop_lon_uts
# 0           NaN
# 1           NaN
# 2    -79.333893
# 3           NaN
# 4    -79.339319
# 5           NaN
# 6    -79.341181
# 7    -79.346600
# 8    -79.350256
#
# [9 rows x 21 columns]

# %%
# %lprun -f update_shortest_path update_shortest_path(input_shortest_path, upcoming_trip_stops, td(hours = 19), 917)
# Out:
# Timer unit: 1e-06 s
#
# Total time: 0.02572 s
# File: <ipython-input-205-68356ea5be88>
# Function: update_shortest_path at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def update_shortest_path(s_path, upcoming_trip_stops, current_time_delta, visiting_stop_id):
#      2
#      3                                               #s_path = s_path.set_index('stop_id')
#      4                                               #upcoming_trip_stops = upcoming_trip_stops.set_index('stop_id')
#      5
#      6         1       7121.0   7121.0     27.7      s_path = s_path.join(upcoming_trip_stops, on = 'stop_id', how = 'left', rsuffix = '_uts')
#      7
#      8         2        151.0     75.5      0.6      s_path.previous_stop = np.where(
#      9         1        250.0    250.0      1.0          s_path.stop_time_delta.values < s_path.arrival_time_delta.values,
#     10         1          0.0      0.0      0.0          visiting_stop_id,
#     11         1         62.0     62.0      0.2          s_path.previous_stop.values
#     12                                               )
#     13         2        220.0    110.0      0.9      s_path.previous_mode = np.where(
#     14         1        163.0    163.0      0.6          s_path.stop_time_delta.values < s_path.arrival_time_delta.values,
#     15         1          0.0      0.0      0.0          'T',
#     16         1         60.0     60.0      0.2          s_path.previous_mode.values
#     17                                               )
#     18         2        440.0    220.0      1.7      s_path.trip_id = np.where(
#     19         1        167.0    167.0      0.6          s_path.stop_time_delta.values < s_path.arrival_time_delta.values,
#     20         1         62.0     62.0      0.2          s_path.trip_id_uts.values,
#     21         1         57.0     57.0      0.2          s_path.trip_id.values
#     22                                               )
#     23         2        185.0     92.5      0.7      s_path.arrival_time_delta = np.where(
#     24         1        182.0    182.0      0.7          s_path.stop_time_delta.values < s_path.arrival_time_delta.values,
#     25         1         22.0     22.0      0.1          s_path.stop_time_delta.values,
#     26         1         18.0     18.0      0.1          s_path.arrival_time_delta.values
#     27                                               )
#     28
#     29         1        217.0    217.0      0.8      s_path.loc[visiting_stop_id, 'visited'] = True
#     30         1      13356.0  13356.0     51.9      s_path = s_path.sort_values(by = 'arrival_time_delta').reset_index(drop = False)
#     31
#     32         1       2987.0   2987.0     11.6      return s_path.loc[:, 'stop_id':'visited']

# %% [markdown]
# ## update walking path

# %%
def update_walking_path(shortest_path, current_time_delta, visiting_stop_id):
    visiting_stop_lat = stops.loc[stops.stop_id == visiting_stop_id, 'stop_lat'].values[0]
    visiting_stop_lon = stops.loc[stops.stop_id == visiting_stop_id, 'stop_lon'].values[0]
    walking_distance = abs(shortest_path['stop_lat'] - visiting_stop_lat) + abs(shortest_path['stop_lon'] - visiting_stop_lon)
    walking_x    
    mask = shortest_path.arrival_time_delta > shortest_path.walking_arrival_time_delta
    shortest_path.loc[mask, 'arrival_time_delta'] = shortest_path.loc[mask, 'walking_arrival_time_delta']
    shortest_path.loc[mask, 'previous_stop'] = visiting_stop_id
    shortest_path.loc[mask, 'previous_mode'] = 'W'
    shortest_path.loc[mask, 'trip_id'] = None
    
    shortest_path = shortest_path.sort_values(by = 'arrival_time_delta').reset_index(drop = True)
    shortest_path = shortest_path.drop(columns = 'walking_arrival_time_delta')
    
    return shortest_path

# %% [markdown]
# ---
# ## Define Master Function

# %%
def find_shortest_path(start_lat, start_lon, end_lat, end_lon, start_time_delta):
    
    start_stop_id = find_closest_stop_id(start_lat, start_lon)
    shortest_path = build_shortest_path(stops_mini, start_stop_id, start_time_delta)
    
    #for i in range(0, len(shortest_path)):
    for i in range(0, 94):
                
        next_stop_record = shortest_path.loc[shortest_path.visited == False].iloc[0]
        current_stop_id = next_stop_record.stop_id
        current_time_delta = next_stop_record.arrival_time_delta
        previous_mode = next_stop_record.previous_mode
                
        if (previous_mode == 'T'):
            shortest_path = update_walking_path(shortest_path, current_time_delta, current_stop_id)
        stop_schedule = build_stop_schedule(current_stop_id, current_time_delta)
        upcoming_trip_stops = build_upcoming_trip_stops(stop_schedule)
        shortest_path = update_shortest_path(shortest_path, upcoming_trip_stops, current_time_delta, current_stop_id)
        
    return shortest_path

# %% [markdown]
# ---
# ## Test Functions

# %%
home = [43.76008911645013, -79.33181124795766]
longos = [43.75447805630398, -79.35689569243047]
gonoe = [43.7459232592541, -79.34612864369309]
current_time_delta = td(hours = 19, minutes = 0, seconds = 0)

# %%
# %%time

output = find_shortest_path(home[0], home[1], longos[0], longos[1], td(hours = 19))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-56-99157c19f2ab> in find_shortest_path(start_lat, start_lon, end_lat, end_lon, start_time_delta)
#       8
#       9         next_stop_record = shortest_path.loc[shortest_path.visited == False].iloc[0]
# ---> 10         current_stop_id = next_stop_record.stop_id
#      11         current_time_delta = next_stop_record.arrival_time_delta
#      12         previous_mode = next_stop_record.previous_mode
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5581         ):
#    5582             return self[name]
# -> 5583         return object.__getattribute__(self, name)
#    5584
#    5585     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'stop_id'

# %%
output
# Out:
#       stop_id  stop_code                                          stop_name  \
# 0         917       9083     York Mills Rd at Sandover Dr (1222 York Mills)
# 1        8081       9088         York Mills Rd at Valley Woods Rd East Side
# 2       10256      11533                                113 Valley Woods Rd
# 3        6913      11527                   Valley Woods Rd at York Mills Rd
# 4        5191      11397                            1200-1202 York Mills Rd
# ...       ...        ...                                                ...
# 9414     4305       1632             The West Mall at Sherway Dr North Side
# 9415     7093       1631  The West Mall at Trillium Health Centre (North...
# 9416      880       1633  The West Mall at Sherway Dr (Trillium Health C...
# 9417      477       4435                                   Long Branch Loop
# 9418     1750       5511                                   Long Branch Loop
#
#        stop_lat   stop_lon arrival_time_delta  previous_stop previous_mode  \
# 0     43.759813 -79.331751    0 days 19:00:00            917             W
# 1     43.759595 -79.332036    0 days 19:00:35            917             W
# 2     43.758960 -79.332778    0 days 19:02:12            917             W
# 3     43.758994 -79.333070    0 days 19:02:30            917             W
# 4     43.759132 -79.333893    0 days 19:03:18            917             W
# ...         ...        ...                ...            ...           ...
# 9414  43.609781 -79.560638    1 days 02:22:38            917             W
# 9415  43.610381 -79.561480    1 days 02:22:55            917             W
# 9416  43.609464 -79.560579    1 days 02:22:56            917             W
# 9417  43.592111 -79.543700    1 days 02:23:29            917             W
# 9418  43.591811 -79.544124    1 days 02:24:20            917             W
#
#      trip_id  visited
# 0       None    False
# 1       None    False
# 2       None    False
# 3       None    False
# 4       None    False
# ...      ...      ...
# 9414    None    False
# 9415    None    False
# 9416    None    False
# 9417    None    False
# 9418    None    False
#
# [9419 rows x 10 columns]

# %%
output.head(50)
# Out:
#     stop_id  stop_code                                          stop_name  \
# 0       917       9083     York Mills Rd at Sandover Dr (1222 York Mills)
# 1      8081       9088         York Mills Rd at Valley Woods Rd East Side
# 2     10256      11533                                113 Valley Woods Rd
# 3      6913      11527                   Valley Woods Rd at York Mills Rd
# 4      5191      11397                            1200-1202 York Mills Rd
# 5      4880       9072                        York Mills Rd at Fenside Dr
# 6      6061       9073                        York Mills Rd at Fenside Dr
# 7      6223      13959              Lynedock Cres at Fenside Dr East Side
# 8     10406      11532                        Opposite 44 Valley Woods Rd
# 9      6235      13958                         Fenside Dr at Slidell Cres
# 10     6943      13955        Roywood Dr at Marbury Cres (East) East Side
# 11     5056      11528                                 44 Valley Woods Rd
# 12     6379      13953                       Underpass Gate at Roywood Dr
# 13     1421      13956                  Roywood Dr at Marbury Cres (East)
# 14     3590      13954             Underpass Gate at Roywood Dr West Side
# 15     2549      11531                                 29 Valley Woods Rd
# 16     9683      13957                Roywood Dr at Fenside Dr South Side
# 17     2938      11529                        Opposite 29 Valley Woods Rd
# 18     3235      11530                   Valley Woods Rd at Brookbanks Dr
# 19     2406       7567                   Brookbanks Dr at Valley Woods Rd
# 20     8836       7566                   Brookbanks Dr at Valley Woods Rd
# 21     1708      13951             Underpass Gate at Fenelon Dr East Side
# 22     4192      13952                       Underpass Gate at Fenelon Dr
# 23     8879       9075                     York Mills Rd at Laurentide Dr
# 24     7656      13963                 Roywood Dr at Fortrose Cres (West)
# 25     3177       8025              Parkwoods Village Dr at Brookbanks Dr
# 26     4603      13960                        Lynedock Cres at Climans Rd
# 27     6691       8024              Parkwoods Village Dr at Brookbanks Dr
# 28     7238       9079                    York Mills Rd at Lochinvar Cres
# 29     4895       8029                 Parkwoods Village Dr at Gisburn Rd
# 30     2171       8379                      Underhill Dr at Brookbanks Dr
# 31     4239      13949                      Fenelon Dr at Graydon Hall Dr
# 32     1888       8378           Underhill Dr at Brookbanks Dr South Side
# 33     9569      13950           Fenelon Dr at Graydon Hall Dr South Side
# 34     8969       8028                Parkwoods Village Dr at Gailong Crt
# 35     3984      13685              Yorkland Blvd (South) at Consumers Rd
# 36     7195      11106                 Three Valleys Dr at Groveland Cres
# 37     4036      10252    Yorkland Blvd (South) at Consumers Rd West Side
# 38     2330      13962                 Roywood Dr at Fortrose Cres (East)
# 39     5738       9087                      York Mills Rd at Valentine Dr
# 40     6666      13686                                   251 Consumers Rd
# 41     1835       6321                                   250 Consumers Rd
# 42     4022       8103                   Silverdale Cres at York Mills Rd
# 43     8678       7913                      Laurentide Dr at Larabee Cres
# 44     9007      11534        Silverdale Cres at York Mills Rd South Side
# 45     8319       8380  Underhill Dr at Cassandra Blvd (North) South Side
# 46     3366       9085                   York Mills Rd at Silverdale Cres
# 47     6178       8381             Underhill Dr at Cassandra Blvd (North)
# 48     6219       8367                  Three Valleys Dr at Laurentide Dr
# 49     9304       7917                  Laurentide Dr at Three Valleys Dr
#
#      stop_lat   stop_lon arrival_time_delta  previous_stop previous_mode  \
# 0   43.759813 -79.331751    0 days 19:00:00            917             W
# 1   43.759595 -79.332036    0 days 19:00:35            917             W
# 2   43.758960 -79.332778    0 days 19:02:12            917             W
# 3   43.758994 -79.333070    0 days 19:02:30            917             W
# 4   43.759132 -79.333893    0 days 19:03:18            917             W
# 5   43.760561 -79.327819    0 days 19:05:28            917             W
# 6   43.760782 -79.327546    0 days 19:06:03            917             W
# 7   43.761865 -79.328158    0 days 19:06:36            917             W
# 8   43.755229 -79.333336    0 days 19:07:12            917             W
# 9   43.763310 -79.329061    0 days 19:07:14            917             W
# 10  43.764386 -79.333450    0 days 19:07:20            917             W
# 11  43.755137 -79.333446    0 days 19:07:27            917             W
# 12  43.762471 -79.335600    0 days 19:07:36            917             W
# 13  43.764221 -79.333938    0 days 19:07:42            917             W
# 14  43.762551 -79.335751    0 days 19:07:52            917             W
# 15  43.753958 -79.332910    0 days 19:08:12            917             W
# 16  43.765137 -79.329915    0 days 19:08:22            917             W
# 17  43.753842 -79.333227    0 days 19:08:42            917             W
# 18  43.752396 -79.331912    0 days 19:08:51            917             W
# 19  43.752304 -79.331617    0 days 19:08:56            917             W
# 20  43.752164 -79.331971    0 days 19:09:12            917             W
# 21  43.762033 -79.337416    0 days 19:09:13            917             W
# 22  43.762094 -79.337600    0 days 19:09:30            917             W
# 23  43.757636 -79.338064    0 days 19:09:55            917             W
# 24  43.765905 -79.329219    0 days 19:10:04            917             W
# 25  43.760930 -79.323736    0 days 19:10:40            917             W
# 26  43.762316 -79.324862    0 days 19:10:58            917             W
# 27  43.760994 -79.323484    0 days 19:11:02            917             W
# 28  43.757624 -79.339319    0 days 19:11:24            917             W
# 29  43.760085 -79.321793    0 days 19:11:57            917             W
# 30  43.753391 -79.327649    0 days 19:12:18            917             W
# 31  43.763443 -79.338922    0 days 19:12:37            917             W
# 32  43.753216 -79.327525    0 days 19:12:39            917             W
# 33  43.763361 -79.339040    0 days 19:12:40            917             W
# 34  43.759388 -79.321096    0 days 19:12:57            917             W
# 35  43.771042 -79.331989    0 days 19:13:24            917             W
# 36  43.751639 -79.335076    0 days 19:13:26            917             W
# 37  43.771161 -79.331982    0 days 19:13:32            917             W
# 38  43.765953 -79.326021    0 days 19:13:52            917             W
# 39  43.757207 -79.341181    0 days 19:14:04            917             W
# 40  43.770370 -79.330219    0 days 19:14:07            917             W
# 41  43.770565 -79.330154    0 days 19:14:26            917             W
# 42  43.756875 -79.341192    0 days 19:14:28            917             W
# 43  43.752395 -79.336977    0 days 19:14:46            917             W
# 44  43.756605 -79.341245    0 days 19:14:50            917             W
# 45  43.752430 -79.326374    0 days 19:14:54            917             W
# 46  43.756849 -79.341547    0 days 19:14:54            917             W
# 47  43.752467 -79.326211    0 days 19:15:03            917             W
# 48  43.751485 -79.336354    0 days 19:15:06            917             W
# 49  43.751768 -79.336782    0 days 19:15:16            917             W
#
#    trip_id  visited
# 0     None    False
# 1     None    False
# 2     None    False
# 3     None    False
# 4     None    False
# 5     None    False
# 6     None    False
# 7     None    False
# 8     None    False
# 9     None    False
# 10    None    False
# 11    None    False
# 12    None    False
# 13    None    False
# 14    None    False
# 15    None    False
# 16    None    False
# 17    None    False
# 18    None    False
# 19    None    False
# 20    None    False
# 21    None    False
# 22    None    False
# 23    None    False
# 24    None    False
# 25    None    False
# 26    None    False
# 27    None    False
# 28    None    False
# 29    None    False
# 30    None    False
# 31    None    False
# 32    None    False
# 33    None    False
# 34    None    False
# 35    None    False
# 36    None    False
# 37    None    False
# 38    None    False
# 39    None    False
# 40    None    False
# 41    None    False
# 42    None    False
# 43    None    False
# 44    None    False
# 45    None    False
# 46    None    False
# 47    None    False
# 48    None    False
# 49    None    False

# %%
# current best mini run benchmark
# %lprun -f find_shortest_path find_shortest_path(home[0], home[1], longos[0], longos[1], current_time_delta)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: Timedelta('0 days 19:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-213-8ff904e9cfe7> in <module>
#       1 # current best mini run benchmark
# ----> 2 get_ipython().run_line_magic('lprun', '-f find_shortest_path find_shortest_path(home[0], home[1], longos[0], longos[1], current_time_delta)')
#
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2325                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2326             with self.builtin_trap:
# -> 2327                 result = fn(*args, **kwargs)
#    2328             return result
#    2329
#
# <decorator-gen-117> in lprun(self, parameter_s)
#
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /opt/anaconda3/lib/python3.8/site-packages/line_profiler/line_profiler.py in lprun(self, parameter_s)
#     336         try:
#     337             try:
# --> 338                 profile.runctx(arg_str, global_ns, local_ns)
#     339                 message = ''
#     340             except SystemExit:
#
# /opt/anaconda3/lib/python3.8/site-packages/line_profiler/line_profiler.py in runctx(self, cmd, globals, locals)
#     123         self.enable_by_count()
#     124         try:
# --> 125             exec(cmd, globals, locals)
#     126         finally:
#     127             self.disable_by_count()
#
# <string> in <module>
#
# <ipython-input-212-64d50c5910bc> in find_shortest_path(start_lat, start_lon, end_lat, end_lon, start_time_delta)
#       7     for i in range(0, 940):
#       8
# ----> 9         next_stop_record = shortest_path.loc[shortest_path.visited == False].loc[shortest_path.arrival_time_delta.min()]
#      10         current_stop_id = next_stop_record.stop_id
#      11         current_time_delta = next_stop_record.arrival_time_delta
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     965
#     966             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967             return self._getitem_axis(maybe_callable, axis=axis)
#     968
#     969     def _is_scalar_access(self, key: tuple):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1200         # fall thru to straight lookup
#    1201         self._validate_key(key, axis)
# -> 1202         return self._get_label(key, axis=axis)
#    1203
#    1204     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1151     def _get_label(self, label, axis: int):
#    1152         # GH#5667 this will fail if the label is not present in the axis.
# -> 1153         return self.obj.xs(label, axis=axis)
#    1154
#    1155     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3874                     new_index = index[loc]
#    3875         else:
# -> 3876             loc = index.get_loc(key)
#    3877
#    3878             if isinstance(loc, np.ndarray):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
# -> 3623                 raise KeyError(key) from err
#    3624             except TypeError:
#    3625                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: Timedelta('0 days 19:00:00')
